# %%
# !git config --global user.email "marcin.byra@gmail.com"
# !git config --global user.name "komisarzGiT"

# %%
# !git clone https://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@github.com/komisarzGiT/gai.git
# Out:
# Cloning into 'gai'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/GAI_exercises.ipynb"
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/Colab Notebooks/GAI_exercises.ipynb'
# Try 'cp --help' for more information.

# %%
# !rm -rf gai
